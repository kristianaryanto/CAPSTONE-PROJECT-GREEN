# %% [markdown]
# ## train pm10 library

# %%
import d1pm10 as pm10
# Out:
# 2022-06-08 23:34:14.569101: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# 2022-06-08 23:34:14.569154: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# Epoch 1/70
# 2022-06-08 23:34:24.689325: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcuda.so.1'; dlerror: libcuda.so.1: cannot open shared object file: No such file or directory
# 2022-06-08 23:34:24.689371: W tensorflow/stream_executor/cuda/cuda_driver.cc:269] failed call to cuInit: UNKNOWN ERROR (303)
# 2022-06-08 23:34:24.689396: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (yance-pc): /proc/driver/nvidia/version does not exist
# ...

# %% [markdown]
# ## train pm25 library

# %%
import d1pm25 as pm25
# Out:
# Epoch 1/70
# 10/10 [==============================] - 1s 7ms/step - loss: 71.4812 - LogCoshError: 71.2881 - lr: 1.0000e-08
# Epoch 2/70
# 10/10 [==============================] - 0s 2ms/step - loss: 71.4608 - LogCoshError: 71.2677 - lr: 1.1220e-08
# Epoch 3/70
# 10/10 [==============================] - 0s 2ms/step - loss: 71.4290 - LogCoshError: 71.2359 - lr: 1.2589e-08
# Epoch 4/70
# 10/10 [==============================] - 0s 3ms/step - loss: 71.3904 - LogCoshError: 71.1973 - lr: 1.4125e-08
# Epoch 5/70
# 10/10 [==============================] - 0s 2ms/step - loss: 71.3460 - LogCoshError: 71.1528 - lr: 1.5849e-08
# Epoch 6/70
# 10/10 [==============================] - 0s 2ms/step - loss: 71.2957 - LogCoshError: 71.1026 - lr: 1.7783e-08
# Epoch 7/70
# 10/10 [==============================] - 0s 2ms/step - loss: 71.2392 - LogCoshError: 71.0461 - lr: 1.9953e-08
# Epoch 8/70
# 10/10 [==============================] - 0s 2ms/step - loss: 71.1748 - LogCoshError: 70.9816 - lr: 2.2387e-08
# ...

# %% [markdown]
# ## train so2 library

# %%
import d1so2 as so2
# Out:
# Epoch 1/70
# 10/10 [==============================] - 1s 7ms/step - loss: 28.3235 - LogCoshError: 28.1304 - lr: 1.0000e-08
# Epoch 2/70
# 10/10 [==============================] - 0s 3ms/step - loss: 28.3198 - LogCoshError: 28.1267 - lr: 1.1220e-08
# Epoch 3/70
# 10/10 [==============================] - 0s 3ms/step - loss: 28.3141 - LogCoshError: 28.1210 - lr: 1.2589e-08
# Epoch 4/70
# 10/10 [==============================] - 0s 2ms/step - loss: 28.3071 - LogCoshError: 28.1140 - lr: 1.4125e-08
# Epoch 5/70
# 10/10 [==============================] - 0s 2ms/step - loss: 28.2991 - LogCoshError: 28.1060 - lr: 1.5849e-08
# Epoch 6/70
# 10/10 [==============================] - 0s 2ms/step - loss: 28.2900 - LogCoshError: 28.0969 - lr: 1.7783e-08
# Epoch 7/70
# 10/10 [==============================] - 0s 2ms/step - loss: 28.2799 - LogCoshError: 28.0868 - lr: 1.9953e-08
# Epoch 8/70
# 10/10 [==============================] - 0s 3ms/step - loss: 28.2686 - LogCoshError: 28.0754 - lr: 2.2387e-08
# ...

# %% [markdown]
# ## train co library

# %%
import d1co as co
# Out:
# Epoch 1/70
# 10/10 [==============================] - 1s 7ms/step - loss: 14.0383 - LogCoshError: 13.8452 - lr: 1.0000e-08
# Epoch 2/70
# 10/10 [==============================] - 0s 2ms/step - loss: 14.0376 - LogCoshError: 13.8445 - lr: 1.1220e-08
# Epoch 3/70
# 10/10 [==============================] - 0s 2ms/step - loss: 14.0366 - LogCoshError: 13.8434 - lr: 1.2589e-08
# Epoch 4/70
# 10/10 [==============================] - 0s 2ms/step - loss: 14.0353 - LogCoshError: 13.8421 - lr: 1.4125e-08
# Epoch 5/70
# 10/10 [==============================] - 0s 2ms/step - loss: 14.0337 - LogCoshError: 13.8406 - lr: 1.5849e-08
# Epoch 6/70
# 10/10 [==============================] - 0s 2ms/step - loss: 14.0320 - LogCoshError: 13.8389 - lr: 1.7783e-08
# Epoch 7/70
# 10/10 [==============================] - 0s 3ms/step - loss: 14.0301 - LogCoshError: 13.8370 - lr: 1.9953e-08
# Epoch 8/70
# 10/10 [==============================] - 0s 2ms/step - loss: 14.0280 - LogCoshError: 13.8349 - lr: 2.2387e-08
# ...

# %% [markdown]
# ## train o3 library

# %%
import d1o3 as o3
# Out:
# Epoch 1/70
# 10/10 [==============================] - 1s 7ms/step - loss: 31.4814 - LogCoshError: 31.2882 - lr: 1.0000e-08
# Epoch 2/70
# 10/10 [==============================] - 0s 2ms/step - loss: 31.4786 - LogCoshError: 31.2854 - lr: 1.1220e-08
# Epoch 3/70
# 10/10 [==============================] - 0s 2ms/step - loss: 31.4742 - LogCoshError: 31.2811 - lr: 1.2589e-08
# Epoch 4/70
# 10/10 [==============================] - 0s 2ms/step - loss: 31.4690 - LogCoshError: 31.2758 - lr: 1.4125e-08
# Epoch 5/70
# 10/10 [==============================] - 0s 2ms/step - loss: 31.4629 - LogCoshError: 31.2698 - lr: 1.5849e-08
# Epoch 6/70
# 10/10 [==============================] - 0s 2ms/step - loss: 31.4561 - LogCoshError: 31.2629 - lr: 1.7783e-08
# Epoch 7/70
# 10/10 [==============================] - 0s 2ms/step - loss: 31.4483 - LogCoshError: 31.2552 - lr: 1.9953e-08
# Epoch 8/70
# 10/10 [==============================] - 0s 3ms/step - loss: 31.4397 - LogCoshError: 31.2465 - lr: 2.2387e-08
# ...

# %% [markdown]
# ## train no2 library

# %%
import d1no2 as no2
# Out:
# Epoch 1/70
# 10/10 [==============================] - 1s 7ms/step - loss: 24.1499 - LogCoshError: 23.9567 - lr: 1.0000e-08
# Epoch 2/70
# 10/10 [==============================] - 0s 3ms/step - loss: 24.1489 - LogCoshError: 23.9557 - lr: 1.1220e-08
# Epoch 3/70
# 10/10 [==============================] - 0s 2ms/step - loss: 24.1474 - LogCoshError: 23.9543 - lr: 1.2589e-08
# Epoch 4/70
# 10/10 [==============================] - 0s 2ms/step - loss: 24.1457 - LogCoshError: 23.9525 - lr: 1.4125e-08
# Epoch 5/70
# 10/10 [==============================] - 0s 2ms/step - loss: 24.1437 - LogCoshError: 23.9505 - lr: 1.5849e-08
# Epoch 6/70
# 10/10 [==============================] - 0s 2ms/step - loss: 24.1414 - LogCoshError: 23.9482 - lr: 1.7783e-08
# Epoch 7/70
# 10/10 [==============================] - 0s 3ms/step - loss: 24.1389 - LogCoshError: 23.9457 - lr: 1.9953e-08
# Epoch 8/70
# 10/10 [==============================] - 0s 3ms/step - loss: 24.1360 - LogCoshError: 23.9429 - lr: 2.2387e-08
# ...

# %%
import d1co2 as co2
# Out:
# Epoch 1/40
# 10/10 [==============================] - 1s 6ms/step - loss: 1099.9077 - LogCoshError: 1099.7146 - lr: 1.0000e-08
# Epoch 2/40
# 10/10 [==============================] - 0s 2ms/step - loss: 1094.5491 - LogCoshError: 1094.3560 - lr: 1.1220e-08
# Epoch 3/40
# 10/10 [==============================] - 0s 3ms/step - loss: 1086.0557 - LogCoshError: 1085.8624 - lr: 1.2589e-08
# Epoch 4/40
# 10/10 [==============================] - 0s 2ms/step - loss: 1075.5767 - LogCoshError: 1075.3837 - lr: 1.4125e-08
# Epoch 5/40
# 10/10 [==============================] - 0s 2ms/step - loss: 1063.6056 - LogCoshError: 1063.4125 - lr: 1.5849e-08
# Epoch 6/40
# 10/10 [==============================] - 0s 2ms/step - loss: 1050.0776 - LogCoshError: 1049.8845 - lr: 1.7783e-08
# Epoch 7/40
# 10/10 [==============================] - 0s 3ms/step - loss: 1034.5046 - LogCoshError: 1034.3115 - lr: 1.9953e-08
# Epoch 8/40
# ...

# %% [markdown]
# ## show output date

# %%
import pandas as pd

df = pm10.pm10()
df2 = pm25.pm25()
df3 = so2.so2()
df4 = co.co()
df5 = o3.o3()
df6 = no2.no2()
df7 = co2.co2()

frame = [df,df2,df3,df4,df5,df6,df7]
ttl = pd.concat(frame)
#print(df,df2,df3,df4,df5,df6,df7)
print(ttl)
#ttl.to_csv('/home/yance/Capstone_Project/NewFolder/dki5.csv')
# Out:
#         tanggal      Value
# 0    2021-10-28  56.721745
# 1    2021-10-29  50.900585
# 2    2021-10-30  50.768291
# 3    2021-10-31  53.950825
# 4    2021-11-01  53.919487
# ..          ...        ...
# 425  2022-12-27  48.034931
# 426  2022-12-28  48.909058
# 427  2022-12-29  52.534969
# 428  2022-12-30  37.415890
# 429  2022-12-31  56.780987
#
# [430 rows x 2 columns]
#         tanggal      Value
# 0    2021-10-28  78.967049
# 1    2021-10-29  78.502846
# 2    2021-10-30  74.565651
# 3    2021-10-31  75.044113
# 4    2021-11-01  82.424217
# ..          ...        ...
# 425  2022-12-27  68.704514
# 426  2022-12-28  67.551857
# 427  2022-12-29  76.530327
# 428  2022-12-30  63.927273
# 429  2022-12-31  70.623344
#
# [430 rows x 2 columns]
#         tanggal      Value
# 0    2021-10-28  31.006990
# 1    2021-10-29  33.046215
# 2    2021-10-30  34.307961
# 3    2021-10-31  35.208504
# 4    2021-11-01  33.868282
# ..          ...        ...
# 425  2022-12-27  22.544151
# ...
